# %%
import pandas as pd
import numpy as np
import os
from tqdm import tqdm_notebook

# %%
def prepare_data(path, target):
    raw_df = pd.read_csv(path)
    
    site_names = ['site{}'.format(i) for i in range(1, 11)]
    time_names = ['time{}'.format(i) for i in range(1, 11)]
    feature_names = [None] * (2 * len(site_names))
    feature_names[1::2] = time_names
    feature_names[::2] = site_names
    
    # prepare 30-min steps
    raw_df['timestamp'] = pd.to_datetime(raw_df['timestamp'])
    time_diff = raw_df['timestamp'].diff().astype(int)
    time_diff = np.where(time_diff < 0, np.nan, time_diff)
    raw_df['min_diff'] = time_diff/(1e9*60)
    raw_df['min_diff'].fillna(0, inplace = True)
    raw_df['min_cumsum'] = raw_df['min_diff'].cumsum()
    raw_df['step'] = (raw_df['min_cumsum']//30).astype(int)
    
#     return raw_df
    
    step_list = raw_df['step'].unique()
    
    stacking_list = []
    for step in step_list:
        temp_part = raw_df[raw_df['step'] == step][['timestamp', 'site']].to_numpy()
        
#         print(temp_part.shape[0])
        
        # infill matrix by NaN`s
        if temp_part.shape[0]%10 != 0:
            temp_padding = np.full((10 - temp_part.shape[0]%10, 2), np.nan)
            temp_part = np.vstack([temp_part, temp_padding])

        # https://stackoverflow.com/questions/3678869/pythonic-way-to-combine-two-lists-in-an-alternating-fashion
        temp_combine = [None] * (2 * len(temp_part))
        temp_combine[1::2] = temp_part[:, 0]
        temp_combine[::2] = temp_part[:, 1]

        temp_result = np.array(temp_combine).reshape((-1, 20))
        stacking_list.append(temp_result)

    data = np.vstack(stacking_list)
    
    df = pd.DataFrame(data, columns = feature_names)
    df['target'] = np.full(df.shape[0], target)
    
    return df

# %%
alice_path = 'Data/raw_train/Alice_log.csv'

# %%
# %%time
alice_df = prepare_data(alice_path, target = 1)
# Out:
# CPU times: user 252 ms, sys: 4.3 ms, total: 256 ms
# Wall time: 260 ms

# %%
alice_df.head()
# Out:
#               site1               time1                site2  \
# 0      api.bing.com 2013-02-12 16:25:10         api.bing.com
# 1  www.facebook.com 2013-02-12 16:32:27  www.info-jeunes.net
# 2  www.facebook.com 2013-02-12 16:32:53  www.info-jeunes.net
# 3      www.bing.com 2013-02-12 16:33:50         www.bing.com
# 4    193.164.197.30 2013-02-12 16:33:55     www.leboncoin.fr
#
#                 time2                site3               time3  \
# 0 2013-02-12 16:25:11         api.bing.com 2013-02-12 16:32:10
# 1 2013-02-12 16:32:28          twitter.com 2013-02-12 16:32:29
# 2 2013-02-12 16:33:11  www.info-jeunes.net 2013-02-12 16:33:12
# 3 2013-02-12 16:33:51     www.leboncoin.fr 2013-02-12 16:33:52
# 4 2013-02-12 16:33:55  static.leboncoin.fr 2013-02-12 16:33:55
#
#                  site4               time4                site5  \
# 0        www.google.fr 2013-02-12 16:32:11        www.google.fr
# 1  www.info-jeunes.net 2013-02-12 16:32:34  www.info-jeunes.net
# 2     www.facebook.com 2013-02-12 16:33:13          twitter.com
# 3         www.bing.com 2013-02-12 16:33:52          twitter.com
# 4       193.164.196.60 2013-02-12 16:33:55       193.164.197.40
#
#                 time5  ...               time6                site7  \
# 0 2013-02-12 16:32:24  ... 2013-02-12 16:32:25        www.google.fr
# 1 2013-02-12 16:32:35  ... 2013-02-12 16:32:35  www.info-jeunes.net
# 2 2013-02-12 16:33:15  ... 2013-02-12 16:33:24     www.facebook.com
# 3 2013-02-12 16:33:52  ... 2013-02-12 16:33:52   deliv.leboncoin.fr
# 4 2013-02-12 16:33:55  ... 2013-02-12 16:33:55       193.164.196.40
#
#                 time7                site8               time8  \
# 0 2013-02-12 16:32:25  www.info-jeunes.net 2013-02-12 16:32:26
# 1 2013-02-12 16:32:42     www.facebook.com 2013-02-12 16:32:42
# 2 2013-02-12 16:33:24  www.info-jeunes.net 2013-02-12 16:33:33
# 3 2013-02-12 16:33:52     www.leboncoin.fr 2013-02-12 16:33:53
# 4 2013-02-12 16:33:55       193.164.197.60 2013-02-12 16:33:55
#
#                   site9               time9               site10  \
# 0  platform.twitter.com 2013-02-12 16:32:27  www.info-jeunes.net
# 1   www.info-jeunes.net 2013-02-12 16:32:51  www.info-jeunes.net
# 2      www.facebook.com 2013-02-12 16:33:34         api.bing.com
# 3    deliv.leboncoin.fr 2013-02-12 16:33:53  static.leboncoin.fr
# 4        193.164.197.50 2013-02-12 16:33:55   deliv.leboncoin.fr
#
#                time10 target
# 0 2013-02-12 16:32:27      1
# 1 2013-02-12 16:32:53      1
# 2 2013-02-12 16:33:46      1
# 3 2013-02-12 16:33:53      1
# 4 2013-02-12 16:33:55      1
#
# [5 rows x 21 columns]

# %%
alice_df.shape
# Out:
# (2327, 21)

# %%
other_user_path = 'Data/raw_train/other_user_logs'

# %%
files_list = sorted([file for file in os.listdir(other_user_path) if 'csv' in file])

# %%
other_users_df = pd.DataFrame(columns = alice_df.columns)

for file_name in tqdm_notebook(files_list):
    temp_df = prepare_data(os.path.join(other_user_path, file_name), target = 0)
    other_users_df = pd.concat([other_users_df, temp_df])
    
other_users_df.reset_index(drop = True, inplace = True)
# Out:
# HBox(children=(IntProgress(value=0, max=1557), HTML(value='')))

# %%
other_users_df
# Out:
#                                       site1               time1  \
# 0                fpdownload2.macromedia.com 2013-11-29 08:14:18
# 1                      dub122.mail.live.com 2013-11-29 08:15:34
# 2                          storage.live.com 2013-11-29 08:15:39
# 3                                h.live.com 2013-11-29 08:17:32
# 4       proxy-bay-people.directory.live.com 2013-11-29 08:45:53
# ...                                     ...                 ...
# 261549                       login.live.com 2014-03-17 16:58:12
# 261550                 dub115.mail.live.com 2014-03-17 16:58:28
# 261551                 dub115.mail.live.com 2014-03-17 16:58:31
# 261552                        go.trouter.io 2014-03-17 16:59:51
# 261553                          twitter.com 2014-03-17 17:00:09
#
#                             site2                time2  \
# 0                      hotmail.fr  2013-11-29 08:14:26
# 1          secure.shared.live.com  2013-11-29 08:15:35
# 2        blufiles.storage.msn.com  2013-11-29 08:15:39
# 3            dub122.mail.live.com  2013-11-29 08:17:36
# 4            dub122.mail.live.com  2013-11-29 08:46:22
# ...                           ...                  ...
# 261549             login.live.com  2014-03-17 16:58:13
# 261550  windowslive.tt.omtrdc.net  2014-03-17 16:58:28
# 261551                 h.live.com  2014-03-17 16:58:33
# 261552           go.microsoft.com  2014-03-17 16:59:51
# 261553   s-static.ak.facebook.com  2014-03-17 17:00:09
#
#                                               site3                time3  \
# 0                                    login.live.com  2013-11-29 08:14:38
# 1                         windowslive.tt.omtrdc.net  2013-11-29 08:15:36
# 2                                        h.live.com  2013-11-29 08:15:39
# 3                              dub122.mail.live.com  2013-11-29 08:18:26
# 4                                        h.live.com  2013-11-29 08:47:26
# ...                                             ...                  ...
# 261549                    windowslive.tt.omtrdc.net  2014-03-17 16:58:15
# 261550  cid-97d7198274048e15.users.storage.live.com  2014-03-17 16:58:28
# 261551                                go.trouter.io  2014-03-17 16:58:33
# 261552                       ieonline.microsoft.com  2014-03-17 16:59:51
# 261553                         platform.twitter.com  2014-03-17 17:00:10
#
#                                               site4                time4  \
# 0                                    login.live.com  2013-11-29 08:14:57
# 1                              dub122.mail.live.com  2013-11-29 08:15:36
# 2                         windowslive.tt.omtrdc.net  2013-11-29 08:15:39
# 3       cid-1bed360223325286.users.storage.live.com  2013-11-29 08:18:31
# 4                              dub122.mail.live.com  2013-11-29 08:47:27
# ...                                             ...                  ...
# 261549                               login.live.com  2014-03-17 16:58:23
# 261550                                   h.live.com  2014-03-17 16:58:29
# 261551                             storage.live.com  2014-03-17 16:58:47
# 261552                    windowslive.tt.omtrdc.net  2014-03-17 16:59:59
# 261553                               login.live.com  2014-03-17 17:00:10
#
#                                       site5                time5  ...  \
# 0                            login.live.com  2013-11-29 08:15:17  ...
# 1                    secure.shared.live.com  2013-11-29 08:15:37  ...
# 2                  prod.registrar.skype.com  2013-11-29 08:15:40  ...
# 3       proxy-bay-people.directory.live.com  2013-11-29 08:21:45  ...
# 4       proxy-bay-people.directory.live.com  2013-11-29 08:50:57  ...
# ...                                     ...                  ...  ...
# 261549                       login.live.com  2014-03-17 16:58:24  ...
# 261550            people.directory.live.com  2014-03-17 16:58:29  ...
# 261551               secure.shared.live.com  2014-03-17 16:59:22  ...
# 261552                     www.facebook.com  2014-03-17 17:00:07  ...
# 261553            login.secure.emea.msn.com  2014-03-17 17:00:11  ...
#
#                       time6                                site7  \
# 0       2013-11-29 08:15:18                        mail.live.com
# 1       2013-11-29 08:15:37                          js.live.net
# 2       2013-11-29 08:15:41                           h.live.com
# 3       2013-11-29 08:24:57  proxy-bay-people.directory.live.com
# 4       2013-11-29 08:59:53             prod.registrar.skype.com
# ...                     ...                                  ...
# 261549  2014-03-17 16:58:24                 dub115.mail.live.com
# 261550  2014-03-17 16:58:29                          js.live.net
# 261551  2014-03-17 16:59:25                             p.sfx.ms
# 261552  2014-03-17 17:00:08                        pbs.twimg.com
# 261553                  NaT                                  NaN
#
#                       time7                                        site8  \
# 0       2013-11-29 08:15:23                         dub122.mail.live.com
# 1       2013-11-29 08:15:37                    people.directory.live.com
# 2       2013-11-29 08:15:41                                   h.live.com
# 3       2013-11-29 08:40:48                         dub122.mail.live.com
# 4       2013-11-29 09:00:19                                   h.live.com
# ...                     ...                                          ...
# 261549  2014-03-17 16:58:24                    windowslive.tt.omtrdc.net
# 261550  2014-03-17 16:58:29                                   h.live.com
# 261551  2014-03-17 16:59:25  cid-97d7198274048e15.users.storage.live.com
# 261552  2014-03-17 17:00:08                      eulerian.canal-plus.com
# 261553                  NaT                                          NaN
#
#                       time8                      site9                time9  \
# 0       2013-11-29 08:15:29  people.directory.live.com  2013-11-29 08:15:30
# 1       2013-11-29 08:15:37             login.live.com  2013-11-29 08:15:38
# 2       2013-11-29 08:15:42     secure.shared.live.com  2013-11-29 08:15:49
# 3       2013-11-29 08:40:49                 h.live.com  2013-11-29 08:40:50
# 4       2013-11-29 09:00:57   prod.registrar.skype.com  2013-11-29 09:00:58
# ...                     ...                        ...                  ...
# 261549  2014-03-17 16:58:24       dub115.mail.live.com  2014-03-17 16:58:26
# 261550  2014-03-17 16:58:30     secure.shared.live.com  2014-03-17 16:58:30
# 261551  2014-03-17 16:59:30                 h.live.com  2014-03-17 16:59:30
# 261552  2014-03-17 17:00:08              pbs.twimg.com  2014-03-17 17:00:09
# 261553                  NaT                        NaN                  NaT
#
#                            site10               time10 target
# 0            dub122.mail.live.com  2013-11-29 08:15:30      0
# 1                   go.trouter.io  2013-11-29 08:15:39      0
# 2                      h.live.com  2013-11-29 08:16:47      0
# 3                             NaN                  NaT      0
# 4                      h.live.com  2013-11-29 09:01:09      0
# ...                           ...                  ...    ...
# 261549  people.directory.live.com  2014-03-17 16:58:27      0
# 261550       dub115.mail.live.com  2014-03-17 16:58:30      0
# 261551       dub115.mail.live.com  2014-03-17 16:59:30      0
# 261552           www.facebook.com  2014-03-17 17:00:09      0
# 261553                        NaN                  NaT      0
#
# [261554 rows x 21 columns]

# %%
other_users_df.shape
# Out:
# (261554, 21)

# %%
result_df = pd.concat([alice_df, other_users_df]).sort_values('time1')

result_df.reset_index(drop = True, inplace = True)
result_df['session_id'] = result_df.index.to_numpy() + 1

# %%
#reorder columns
columns = result_df.columns.to_list()
result_df = result_df[['session_id'] + columns[:-1]]
result_df
# Out:
#         session_id                            site1               time1  \
# 0                1  safebrowsing.clients.google.com 2013-01-12 08:05:57
# 1                2  safebrowsing.clients.google.com 2013-01-12 08:37:23
# 2                3                   www.apache.org 2013-01-12 08:50:13
# 3                4                  www.webtide.com 2013-01-12 08:50:17
# 4                5               public.dhe.ibm.com 2013-01-12 08:50:20
# ...            ...                              ...                 ...
# 263876      263877                ocsp.verisign.com 2014-04-30 23:33:48
# 263877      263878                      dropbox.com 2014-04-30 23:34:15
# 263878      263879              clients1.google.com 2014-04-30 23:38:08
# 263879      263880                 iapref.orange.fr 2014-04-30 23:38:36
# 263880      263881                  ocsp.thawte.com 2014-04-30 23:39:53
#
#                                 site2                time2  \
# 0       safebrowsing-cache.google.com  2013-01-12 08:05:57
# 1       safebrowsing-cache.google.com  2013-01-12 08:37:23
# 2                      www.apache.org  2013-01-12 08:50:14
# 3                 download.oracle.com  2013-01-12 08:50:17
# 4                        jope.ow2.org  2013-01-12 08:50:20
# ...                               ...                  ...
# 263876              ocsp.verisign.com  2014-04-30 23:33:49
# 263877               ocsp.godaddy.com  2014-04-30 23:34:16
# 263878                www.dropbox.com  2014-04-30 23:38:10
# 263879                   c.woopic.com  2014-04-30 23:38:36
# 263880                www.dropbox.com  2014-04-30 23:39:59
#
#                                site3                time3  \
# 0                                NaN                  NaT
# 1                                NaN                  NaT
# 2               download.eclipse.org  2013-01-12 08:50:15
# 3                     www.caucho.com  2013-01-12 08:50:18
# 4                download.oracle.com  2013-01-12 08:50:20
# ...                              ...                  ...
# 263876             ocsp.digicert.com  2014-04-30 23:33:52
# 263877              ocsp.godaddy.com  2014-04-30 23:34:17
# 263878  javadl-esd-secure.oracle.com  2014-04-30 23:38:13
# 263879                  id.orange.fr  2014-04-30 23:38:38
# 263880               www.dropbox.com  2014-04-30 23:40:00
#
#                                site4                time4  \
# 0                                NaN                  NaT
# 1                                NaN                  NaT
# 2                     www.apache.org  2013-01-12 08:50:15
# 3                download.oracle.com  2013-01-12 08:50:18
# 4                 public.dhe.ibm.com  2013-01-12 08:50:21
# ...                              ...                  ...
# 263876       gtssl-ocsp.geotrust.com  2014-04-30 23:33:52
# 263877           clients1.google.com  2014-04-30 23:34:18
# 263878  javadl-esd-secure.oracle.com  2014-04-30 23:38:18
# 263879                   r.orange.fr  2014-04-30 23:38:38
# 263880            dl-web.dropbox.com  2014-04-30 23:40:05
#
#                                 site5  ...                time6  \
# 0                                 NaN  ...                  NaT
# 1                                 NaN  ...                  NaT
# 2                      www.apache.org  ...  2013-01-12 08:50:16
# 3                     www.webtide.com  ...  2013-01-12 08:50:18
# 4                        jope.ow2.org  ...  2013-01-12 08:50:21
# ...                               ...  ...                  ...
# 263876              ocsp.digicert.com  ...  2014-04-30 23:33:53
# 263877              ocsp.verisign.com  ...  2014-04-30 23:35:16
# 263878                www.dropbox.com  ...  2014-04-30 23:38:24
# 263879               ocsp.godaddy.com  ...  2014-04-30 23:38:40
# 263880  safebrowsing-cache.google.com  ...  2014-04-30 23:40:05
#
#                       site7                time7  \
# 0                       NaN                  NaT
# 1                       NaN                  NaT
# 2       download.oracle.com  2013-01-12 08:50:16
# 3        public.dhe.ibm.com  2013-01-12 08:50:19
# 4            www.apache.org  2013-01-12 08:50:21
# ...                     ...                  ...
# 263876  clients1.google.com  2014-04-30 23:33:54
# 263877      www.dropbox.com  2014-04-30 23:35:29
# 263878         c.woopic.com  2014-04-30 23:38:35
# 263879         id.orange.fr  2014-04-30 23:38:40
# 263880      www.dropbox.com  2014-04-30 23:40:05
#
#                                site8                time8               site9  \
# 0                                NaN                  NaT                 NaN
# 1                                NaN                  NaT                 NaN
# 2       javadl-esd-secure.oracle.com  2013-01-12 08:50:16      www.caucho.com
# 3                    www.webtide.com  2013-01-12 08:50:19      www.apache.org
# 4               download.eclipse.org  2013-01-12 08:50:22      www.apache.org
# ...                              ...                  ...                 ...
# 263876       gtssl-ocsp.geotrust.com  2014-04-30 23:33:54     www.mozilla.org
# 263877            dl-web.dropbox.com  2014-04-30 23:36:12     www.dropbox.com
# 263878                     orange.fr  2014-04-30 23:38:35       www.orange.fr
# 263879            dl-web.dropbox.com  2014-04-30 23:39:07  dl-web.dropbox.com
# 263880                           NaN                  NaT                 NaN
#
#                       time9               site10               time10 target
# 0                       NaT                  NaN                  NaT      0
# 1                       NaT                  NaN                  NaT      0
# 2       2013-01-12 08:50:17       www.apache.org  2013-01-12 08:50:17      0
# 3       2013-01-12 08:50:19       www.apache.org  2013-01-12 08:50:20      0
# 4       2013-01-12 08:50:22   public.dhe.ibm.com  2013-01-12 08:50:22      0
# ...                     ...                  ...                  ...    ...
# 263876  2014-04-30 23:33:57      geo.mozilla.org  2014-04-30 23:34:00      0
# 263877  2014-04-30 23:36:42  ajax.googleapis.com  2014-04-30 23:37:13      0
# 263878  2014-04-30 23:38:35          c.orange.fr  2014-04-30 23:38:36      0
# 263879  2014-04-30 23:39:08      www.dropbox.com  2014-04-30 23:39:53      0
# 263880                  NaT                  NaN                  NaT      0
#
# [263881 rows x 22 columns]

# %%
result_df.to_csv('Data/additional_train_data.csv')
